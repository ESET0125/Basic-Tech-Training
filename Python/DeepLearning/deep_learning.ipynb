# %%
pip install tensorflow keras
# Out:
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# ...
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/332.0 MB 8.7 MB/s eta 0:00:39
#    ---------------------------------------- 3.1/332.0 MB 10.2 MB/s eta 0:00:33
#     --------------------------------------- 4.5/332.0 MB 8.6 MB/s eta 0:00:39
#     --------------------------------------- 6.0/332.0 MB 8.2 MB/s eta 0:00:40
#    - -------------------------------------- 8.4/332.0 MB 8.8 MB/s eta 0:00:37
#    - -------------------------------------- 10.7/332.0 MB 9.5 MB/s eta 0:00:34
#    - -------------------------------------- 13.1/332.0 MB 9.7 MB/s eta 0:00:33
# ...

# %%
import tensorflow as tf
import pandas as pd
